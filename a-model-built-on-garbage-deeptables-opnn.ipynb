# %%
# !pip install -q deeptables[gpu]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 15,15
import seaborn as sns

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

import xgboost as xgb
import lightgbm as lgb
from catboost import CatBoostClassifier

from sklearn.model_selection import train_test_split,StratifiedShuffleSplit,StratifiedKFold
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import roc_auc_score,accuracy_score ,confusion_matrix

import warnings
warnings.filterwarnings("ignore")

from imblearn.under_sampling import TomekLinks
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler
from imblearn.combine import SMOTETomek
from imblearn.under_sampling import ClusterCentroids , NearMiss

from tqdm.notebook import tqdm ,tnrange
import deeptables
from deeptables.models.deeptable import DeepTable, ModelConfig
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import LearningRateScheduler , EarlyStopping
import tensorflow as tf
from keras import backend as K
# Out:
# /kaggle/input/lets-get-rid-of-the-patients-feature-engineering/__results__.html
# /kaggle/input/lets-get-rid-of-the-patients-feature-engineering/__output__.json
# /kaggle/input/lets-get-rid-of-the-patients-feature-engineering/custom.css
# /kaggle/input/lets-get-rid-of-the-patients-feature-engineering/__notebook__.ipynb
# /kaggle/input/lets-get-rid-of-the-patients-feature-engineering/combined.csv
# /kaggle/input/healthcareanalyticsii/train.csv
# /kaggle/input/healthcareanalyticsii/train_data_dict.csv
# /kaggle/input/healthcareanalyticsii/test.csv
# /kaggle/input/healthcareanalyticsii/sample_submission.csv

# %%
train_data = pd.read_csv('../input/healthcareanalyticsii/train.csv')
test_data = pd.read_csv('../input/healthcareanalyticsii/test.csv')

# %%
print(train_data.shape)
train_data.head()
# Out:
# (318438, 18)
#    case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0        1              8                  c                   3
# 1        2              2                  c                   5
# 2        3             10                  e                   1
# 3        4             26                  b                   2
# 4        5             26                  b                   2
#
#   Hospital_region_code  Available Extra Rooms in Hospital    Department  \
# 0                    Z                                  3  radiotherapy
# 1                    Z                                  2  radiotherapy
# 2                    X                                  2    anesthesia
# 3                    Y                                  2  radiotherapy
# 4                    Y                                  2  radiotherapy
#
#   Ward_Type Ward_Facility_Code  Bed Grade  patientid  City_Code_Patient  \
# 0         R                  F        2.0      31397                7.0
# 1         S                  F        2.0      31397                7.0
# 2         S                  E        2.0      31397                7.0
# 3         R                  D        2.0      31397                7.0
# 4         S                  D        2.0      31397                7.0
#
#   Type of Admission Severity of Illness  Visitors with Patient    Age  \
# 0         Emergency             Extreme                      2  51-60
# 1            Trauma             Extreme                      2  51-60
# 2            Trauma             Extreme                      2  51-60
# 3            Trauma             Extreme                      2  51-60
# 4            Trauma             Extreme                      2  51-60
#
#    Admission_Deposit   Stay
# 0             4911.0   0-10
# 1             5954.0  41-50
# 2             4745.0  31-40
# 3             7272.0  41-50
# 4             5558.0  41-50

# %%
print(test_data.shape)
test_data.head()
# Out:
# (137057, 17)
#    case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0   318439             21                  c                   3
# 1   318440             29                  a                   4
# 2   318441             26                  b                   2
# 3   318442              6                  a                   6
# 4   318443             28                  b                  11
#
#   Hospital_region_code  Available Extra Rooms in Hospital  Department  \
# 0                    Z                                  3  gynecology
# 1                    X                                  2  gynecology
# 2                    Y                                  3  gynecology
# 3                    X                                  3  gynecology
# 4                    X                                  2  gynecology
#
#   Ward_Type Ward_Facility_Code  Bed Grade  patientid  City_Code_Patient  \
# 0         S                  A        2.0      17006                2.0
# 1         S                  F        2.0      17006                2.0
# 2         Q                  D        4.0      17006                2.0
# 3         Q                  F        2.0      17006                2.0
# 4         R                  F        2.0      17006                2.0
#
#   Type of Admission Severity of Illness  Visitors with Patient    Age  \
# 0         Emergency            Moderate                      2  71-80
# 1            Trauma            Moderate                      4  71-80
# 2         Emergency            Moderate                      3  71-80
# 3            Trauma            Moderate                      3  71-80
# 4            Trauma            Moderate                      4  71-80
#
#    Admission_Deposit
# 0             3095.0
# 1             4018.0
# 2             4492.0
# 3             4173.0
# 4             4161.0

# %%
def nullColumns(train_data):
    list_of_nullcolumns =[]
    for column in train_data.columns:
        total= train_data[column].isna().sum()
        try:
            if total !=0:
                print('Total Na values is {0} for column {1}' .format(total, column))
                list_of_nullcolumns.append(column)
        except:
            print(column,"-----",total)
    print('\n')
    return list_of_nullcolumns


def percentMissingFeature(data):
    data_na = (data.isnull().sum() / len(data)) * 100
    data_na = data_na.drop(data_na[data_na == 0].index).sort_values(ascending=False)[:30]
    missing_data = pd.DataFrame({'Missing Ratio' :data_na})
    return data_na


def plotMissingFeature(data_na):
    f, ax = plt.subplots(figsize=(15, 12))
    plt.xticks(rotation='90')
    if(data_na.empty ==False):
        sns.barplot(x=data_na.index, y=data_na)
        plt.xlabel('Features', fontsize=15)
        plt.ylabel('Percent of missing values', fontsize=15)
        plt.title('Percent missing data by feature', fontsize=15)

# %%
print('train data')
print(nullColumns(train_data))
print(percentMissingFeature(train_data))
print('\n')
print('test_data')
print(nullColumns(test_data))
print(percentMissingFeature(test_data))
# Out:
# train data
# Total Na values is 113 for column Bed Grade
# Total Na values is 4532 for column City_Code_Patient
#
#
# ['Bed Grade', 'City_Code_Patient']
# City_Code_Patient    1.423197
# Bed Grade            0.035486
# dtype: float64
#
#
# test_data
# Total Na values is 35 for column Bed Grade
# Total Na values is 2157 for column City_Code_Patient
#
#
# ['Bed Grade', 'City_Code_Patient']
# City_Code_Patient    1.573798
# Bed Grade            0.025537
# dtype: float64

# %%
stay = train_data.loc[:,"Stay"].value_counts().rename('Count')
plt.xlabel("Stay")
plt.ylabel('Count')
sns.barplot(stay.index , stay.values).set_title('Stay')
# Out:
# Text(0.5, 1.0, 'Stay')

# %%
sns.set(style="white", palette="muted", color_codes=True)

f, axes = plt.subplots(3, 2, figsize=(15, 15))

radiotherapy = train_data[train_data.Department =='radiotherapy']["Stay"].value_counts().rename('Count')

anesthesia = train_data[train_data.Department =='anesthesia']["Stay"].value_counts().rename('Count')

gynecology = train_data[train_data.Department =='gynecology']["Stay"].value_counts().rename('Count')

surgery = train_data[train_data.Department =='surgery']["Stay"].value_counts().rename('Count')

tb = train_data[train_data.Department =='TB & Chest disease']["Stay"].value_counts().rename('Count')

sns.barplot(radiotherapy.index,radiotherapy,  color="b", ax=axes[0, 0]).set_title('Department : radiotherapy')

sns.barplot(anesthesia.index,anesthesia,   color="r", ax=axes[0, 1]).set_title('Department : anesthesia')

sns.barplot(gynecology.index,gynecology,  color="g", ax=axes[1, 0]).set_title('Department : gynecology')

sns.barplot(surgery.index,surgery, color="m", ax=axes[1, 1]).set_title('Department : surgery')

sns.barplot(tb.index,tb, color="m", ax=axes[2, 0]).set_title('Department : TB & Chest disease')

sns.barplot(stay.index,stay, color="m", ax=axes[2, 1]).set_title('Department : ALL')

plt.xlabel("Stay")

plt.setp(axes,yticks = np.arange(0,50000,5000))

for ax in f.axes:
    
    plt.sca(ax)
    
    plt.xticks(rotation=45)

plt.tight_layout()

# %%
sns.set(style="white", palette="muted", color_codes=True)

f, axes = plt.subplots(6, 2, figsize=(15, 15))

stay0 = train_data[train_data.Stay =='0-10']["Department"].value_counts().rename('Count')

stay1 = train_data[train_data.Stay =='11-20']["Department"].value_counts().rename('Count')

stay2 = train_data[train_data.Stay =='21-30']["Department"].value_counts().rename('Count')

stay3 = train_data[train_data.Stay =='31-40']["Department"].value_counts().rename('Count')

stay4 = train_data[train_data.Stay =='41-50']["Department"].value_counts().rename('Count')

stay5 = train_data[train_data.Stay =='51-60']["Department"].value_counts().rename('Count')

stay6 = train_data[train_data.Stay =='61-70']["Department"].value_counts().rename('Count')

stay7 = train_data[train_data.Stay =='71-80']["Department"].value_counts().rename('Count')

stay8 = train_data[train_data.Stay =='81-90']["Department"].value_counts().rename('Count')

stay9 = train_data[train_data.Stay =='91-100']["Department"].value_counts().rename('Count')

stay10 = train_data[train_data.Stay =='More than 100 Days']["Department"].value_counts().rename('Count')

sns.barplot(stay0.index,stay0,  color="b", ax=axes[0, 0]).set_title('Stay : 0-10')
                   
sns.barplot(stay1.index,stay2,  color="r", ax=axes[0, 1]).set_title('Stay : 11-20')

sns.barplot(stay2.index,stay2,  color="b", ax=axes[1, 0]).set_title('Stay : 21-30')

sns.barplot(stay3.index,stay3,  color="g", ax=axes[1, 1]).set_title('Stay : 31-40')

sns.barplot(stay4.index,stay4,  color="b", ax=axes[2, 0]).set_title('Stay : 41-50')

sns.barplot(stay5.index,stay5,  color="b", ax=axes[2, 1]).set_title('Stay : 51-60')

sns.barplot(stay6.index,stay6,  color="m", ax=axes[3, 0]).set_title('Stay : 61-70')

sns.barplot(stay7.index,stay7, color="b", ax=axes[3, 1]).set_title('Stay : 71-80')

sns.barplot(stay8.index,stay8,  color="b", ax=axes[4, 0]).set_title('Stay : 81-90')

sns.barplot(stay9.index,stay9,  color="g", ax=axes[4, 1]).set_title('Stay : 91-100')

sns.barplot(stay10.index,stay10, color="r", ax=axes[5, 0]).set_title('Stay : >100')

plt.setp(axes, yticks = np.arange(0,20000,5000))


for ax in f.axes:
    
    plt.sca(ax)
    
    plt.xticks(rotation=45)

plt.tight_layout()

# %%
sns.set(style="white", palette="muted", color_codes=True)

f, axes = plt.subplots(3, 1, figsize=(15, 15))

emergency = train_data[train_data['Type of Admission'] =='Emergency']["Stay"].value_counts().rename('Count')

trauma = train_data[train_data['Type of Admission'] =='Trauma']["Stay"].value_counts().rename('Count')

urgent = train_data[train_data['Type of Admission'] =='Urgent']["Stay"].value_counts().rename('Count')

sns.barplot(emergency.index,emergency,  color="b", ax=axes[0]).set_title('Admn. Type : Emergency')

sns.barplot(trauma.index,trauma,   color="r", ax=axes[1]).set_title('Admn. Type : Trauma')

sns.barplot(urgent.index,urgent,  color="g", ax=axes[2]).set_title('Admn. Type : Urgent')

plt.setp(axes, yticks = np.arange(0,50000,10000))

for ax in f.axes:
    
    plt.sca(ax)
    
    plt.xticks(rotation=45)

plt.tight_layout()

# %%
train_data['City_Code_Patient'] = train_data['City_Code_Patient'].fillna(-1)
train_data['Bed Grade'] = train_data['Bed Grade'].fillna(-1)

# %%
test_data['City_Code_Patient'] = test_data['City_Code_Patient'].fillna(-1)
test_data['Bed Grade'] = test_data['Bed Grade'].fillna(-1)

# %%
cat_cols = ['Hospital_code','Hospital_type_code','City_Code_Hospital','Hospital_region_code'
            ,'Department','Ward_Type','Ward_Facility_Code','Bed Grade','City_Code_Patient',
           # 'Type of Admission','Severity of Illness',
            'Age']

# %%
label = 'Stay'

# %%
def encode_cat_cols(train, test, cat_cols): #target

    train_df = train_data.copy()
    
    test_df = test_data.copy()
    
    # Making a dictionary to store all the labelencoders for categroical columns to transform them later.
    
    le_dict = {}

    for col in cat_cols:
        
        le = LabelEncoder()
        
        le.fit(train_df[col].unique().tolist() + test_df[col].unique().tolist())
        
        train_df[col] = le.transform(train_df[[col]])
        
        test_df[col] = le.transform(test_df[[col]])

        le_dict[col] = le

    le = LabelEncoder()
    
    train_df[label] = le.fit_transform(train_df[[label]])
    
    le_dict[label] = le
    
    train_df['Type of Admission'] = train_df['Type of Admission'].map({'Urgent':0,'Emergency':1,'Trauma':2})
    
    train_df['Severity of Illness'] = train_df['Severity of Illness'].map({'Minor':0,'Moderate':1,'Extreme':2})
    
    test_df['Type of Admission'] = test_df['Type of Admission'].map({'Urgent':0,'Emergency':1,'Trauma':2})
    
    test_df['Severity of Illness'] = test_df['Severity of Illness'].map({'Minor':0,'Moderate':1,'Extreme':2})
    
    return train_df, test_df, le_dict

# %%
def feature_importance(model, X_train):

    print(model.feature_importances_)
    
    names = X_train.columns.values
    
    ticks = [i for i in range(len(names))]
    
    plt.bar(ticks, model.feature_importances_)
    
    plt.xticks(ticks, names,rotation = 90)
    
    plt.show()

# %%
train_df, test_df, le_dict = encode_cat_cols(train_data,test_data,cat_cols)

# %%
#After Feature Engineering
# https://www.kaggle.com/gcspkmdr/lets-get-rid-of-the-patients-feature-engineering

combined_data = pd.read_csv('../input/lets-get-rid-of-the-patients-feature-engineering/combined.csv')

# %%
train_df = combined_data[combined_data['train']==1]

test_df = combined_data[combined_data['train']==0]

# %%
train_df.drop(columns = ['case_id','train','patientid','Hospital_code',
                         'Hospital_type_code','City_Code_Hospital','Ward_Facility_Code'],inplace = True)

target = train_df.pop('Stay')

test_df.drop(columns = ['case_id','train','Stay','patientid','Hospital_code',
                        'Hospital_type_code','City_Code_Hospital','Ward_Facility_Code'],inplace = True)

# %%
cat_features = ['Hospital_region_code','Department','Ward_Type','Bed Grade','City_Code_Patient','Type of Admission','Severity of Illness','Age']

target = target.astype('category') # you have to tell deep table architecture that your target is categorical otherwise it will treat the problem as one of regression

# %%
sns.heatmap(train_df.corr())

# %% [markdown]
# # Cross Validation
# ![](https://4.bp.blogspot.com/-wpr6O3EBAfU/WbHyt6UCOVI/AAAAAAAAjPw/Y1DaO6qcV8oDYjJHzJ1PaPB2EXHmYtBBQCLcBGAs/s1600/%25E6%2593%25B7%25E5%258F%2596.JPG)
#
# * **The CV score generated using the methodology shown in the above figure is a better indicator of model performance than public LB**

# %%
# Model Parameters

epochs = 100  #keeping this high as i am using lr scheduler

batch_size = 256

seeds = [32,432 ,73]

#Callbacks

early_stop = EarlyStopping(monitor='val_loss', patience = 5 ,restore_best_weights= True)

annealer = LearningRateScheduler(lambda x: 1e-3 * 0.95 ** x) #for plateau

# %%
def build_model():
    
    conf = ModelConfig(dnn_params={'hidden_units':((300, 0.3, True),(300, 0.3, True),), #hidden_units
                                'dnn_activation':'relu',},
                            fixed_embedding_dim=True,
                            embeddings_output_dim=20,
                            nets =['opnn_nets'],
                            stacking_op = 'add',
                            output_use_bias = False,
                            metrics=['accuracy'],
                            categorical_columns = cat_features
                        )
    dt = DeepTable(config = conf)
    
    return dt

# %%
# %%time

##DNN

scores = []

avg_loss = []

X_train_cv,y_train_cv = train_df.copy(), target.copy()

sssf = StratifiedShuffleSplit(n_splits=5, test_size = 0.45 ,random_state=1)

for i, (idxT, idxV) in enumerate(sssf.split(X_train_cv, y_train_cv)):
    
    K.clear_session()
    
    steps_per_epoch = len(X_train_cv.iloc[idxT])//batch_size
        
    validation_steps = len(X_train_cv.iloc[idxV])//batch_size
    
    print('Fold',i)
    
    print(' rows of train =',len(idxT),'rows of holdout =',len(idxV))
    
    dt_cv =  build_model()
    
    model_dnn_cv, history_cv = dt_cv.fit(X_train_cv.iloc[idxT], y_train_cv.iloc[idxT],
                                                 validation_data = (X_train_cv.iloc[idxV],y_train_cv.iloc[idxV]),
                                                 steps_per_epoch = steps_per_epoch,
                                                 validation_steps = validation_steps,
                                                 batch_size=batch_size, epochs=epochs, 
                                                 verbose=0, callbacks=[early_stop,annealer])
    
    val_stats = dt_cv.evaluate(X_train_cv.iloc[idxV],y_train_cv.iloc[idxV], batch_size=batch_size, verbose=0)
    
    acc= val_stats['accuracy']*100
    
    scores.append(acc)
            
    avg_loss.append(val_stats['loss'])
    
    print ('LGB Val CV=',acc)
    
    print('#'*100)
    
    print('\n')
    
print("Multi Log Loss Stats {0:.5f},{1:.5f}".format(np.array(avg_loss).mean(), np.array(avg_loss).std()))

print('%.3f (%.3f)' % (np.array(scores).mean(), np.array(scores).std()))

# !rm -rf './dt_output'
# Out:
# Fold 0
#  rows of train = 175140 rows of holdout = 143298
# 11 class detected, inferred as a [multiclass classification] task
# Preparing features cost:0.09119462966918945
# Imputation cost:0.7347850799560547
# Categorical encoding cost:0.42296361923217773
# fit_transform cost:1.3284485340118408
# transform_X cost:13.564090728759766
# transform_y cost:0.0079193115234375
# 1 Physical GPUs, 1 Logical GPUs
# >>>>>>>>>>>>>>>>>>>>>> Model Desc <<<<<<<<<<<<<<<<<<<<<<<
# ---------------------------------------------------------
# inputs:
# ---------------------------------------------------------
# ['all_categorical_vars: (8)', 'input_continuous_all: (80)']
# ---------------------------------------------------------
# embeddings:
# ---------------------------------------------------------
# input_dims: [5, 7, 8, 7, 40, 5, 5, 12]
# output_dims: [20, 20, 20, 20, 20, 20, 20, 20]
# dropout: 0.3
# ---------------------------------------------------------
# dense: dropout: 0
# batch_normalization: False
# ---------------------------------------------------------
# concat_embed_dense: shape: (None, 240)
# ---------------------------------------------------------
# nets: ['opnn_nets']
# ---------------------------------------------------------
# opnn-outer_product: input_shape list(8), output_shape (None, 28)
# opnn-dnn: input_shape (None, 268), output_shape (None, 300)
# ---------------------------------------------------------
# stacking_op: add
# ---------------------------------------------------------
# output: activation: softmax, output_shape: (None, 11), use_bias: False
# loss: categorical_crossentropy
# optimizer: Adam
# ---------------------------------------------------------
#
# Model has been saved to:dt_output/dt_20200906 074743_opnn_nets/opnn_nets.h5
# transform_X cost:13.359155178070068
# transform_y cost:0.008941411972045898
# LGB Val CV= 43.810102343559265
# ####################################################################################################
#
#
# Fold 1
#  rows of train = 175140 rows of holdout = 143298
# 11 class detected, inferred as a [multiclass classification] task
# Preparing features cost:0.1447899341583252
# Imputation cost:0.6110665798187256
# Categorical encoding cost:0.3649139404296875
# fit_transform cost:1.2101051807403564
# transform_X cost:13.272479772567749
# transform_y cost:0.008083581924438477
# 1 Physical GPUs, 1 Logical GPUs
# >>>>>>>>>>>>>>>>>>>>>> Model Desc <<<<<<<<<<<<<<<<<<<<<<<
# ---------------------------------------------------------
# inputs:
# ---------------------------------------------------------
# ['all_categorical_vars: (8)', 'input_continuous_all: (80)']
# ---------------------------------------------------------
# embeddings:
# ---------------------------------------------------------
# input_dims: [5, 7, 8, 7, 40, 5, 5, 12]
# output_dims: [20, 20, 20, 20, 20, 20, 20, 20]
# dropout: 0.3
# ---------------------------------------------------------
# dense: dropout: 0
# batch_normalization: False
# ---------------------------------------------------------
# concat_embed_dense: shape: (None, 240)
# ---------------------------------------------------------
# nets: ['opnn_nets']
# ---------------------------------------------------------
# opnn-outer_product: input_shape list(8), output_shape (None, 28)
# opnn-dnn: input_shape (None, 268), output_shape (None, 300)
# ---------------------------------------------------------
# stacking_op: add
# ---------------------------------------------------------
# output: activation: softmax, output_shape: (None, 11), use_bias: False
# loss: categorical_crossentropy
# optimizer: Adam
# ---------------------------------------------------------
#
# Model has been saved to:dt_output/dt_20200906 075251_opnn_nets/opnn_nets.h5
# transform_X cost:14.0728759765625
# transform_y cost:0.01094818115234375
# LGB Val CV= 43.75287890434265
# ####################################################################################################
#
#
# Fold 2
#  rows of train = 175140 rows of holdout = 143298
# 11 class detected, inferred as a [multiclass classification] task
# Preparing features cost:0.09770011901855469
# Imputation cost:0.605780839920044
# Categorical encoding cost:0.3602867126464844
# fit_transform cost:1.1412816047668457
# transform_X cost:13.436784982681274
# transform_y cost:0.008079767227172852
# 1 Physical GPUs, 1 Logical GPUs
# >>>>>>>>>>>>>>>>>>>>>> Model Desc <<<<<<<<<<<<<<<<<<<<<<<
# ---------------------------------------------------------
# inputs:
# ---------------------------------------------------------
# ['all_categorical_vars: (8)', 'input_continuous_all: (80)']
# ---------------------------------------------------------
# embeddings:
# ---------------------------------------------------------
# input_dims: [5, 7, 8, 7, 40, 5, 5, 12]
# output_dims: [20, 20, 20, 20, 20, 20, 20, 20]
# dropout: 0.3
# ---------------------------------------------------------
# dense: dropout: 0
# batch_normalization: False
# ---------------------------------------------------------
# concat_embed_dense: shape: (None, 240)
# ---------------------------------------------------------
# nets: ['opnn_nets']
# ---------------------------------------------------------
# opnn-outer_product: input_shape list(8), output_shape (None, 28)
# opnn-dnn: input_shape (None, 268), output_shape (None, 300)
# ---------------------------------------------------------
# stacking_op: add
# ---------------------------------------------------------
# output: activation: softmax, output_shape: (None, 11), use_bias: False
# loss: categorical_crossentropy
# optimizer: Adam
# ---------------------------------------------------------
#
# Model has been saved to:dt_output/dt_20200906 075812_opnn_nets/opnn_nets.h5
# transform_X cost:14.08308744430542
# transform_y cost:0.007778644561767578
# LGB Val CV= 43.94967257976532
# ####################################################################################################
#
#
# Fold 3
#  rows of train = 175140 rows of holdout = 143298
# 11 class detected, inferred as a [multiclass classification] task
# Preparing features cost:0.09111166000366211
# Imputation cost:0.5997109413146973
# Categorical encoding cost:0.36455655097961426
# fit_transform cost:1.13090181350708
# transform_X cost:13.274652004241943
# transform_y cost:0.008116006851196289
# 1 Physical GPUs, 1 Logical GPUs
# >>>>>>>>>>>>>>>>>>>>>> Model Desc <<<<<<<<<<<<<<<<<<<<<<<
# ---------------------------------------------------------
# inputs:
# ---------------------------------------------------------
# ['all_categorical_vars: (8)', 'input_continuous_all: (80)']
# ---------------------------------------------------------
# embeddings:
# ---------------------------------------------------------
# input_dims: [5, 7, 8, 7, 40, 5, 5, 12]
# output_dims: [20, 20, 20, 20, 20, 20, 20, 20]
# dropout: 0.3
# ---------------------------------------------------------
# dense: dropout: 0
# batch_normalization: False
# ---------------------------------------------------------
# concat_embed_dense: shape: (None, 240)
# ---------------------------------------------------------
# nets: ['opnn_nets']
# ---------------------------------------------------------
# opnn-outer_product: input_shape list(8), output_shape (None, 28)
# opnn-dnn: input_shape (None, 268), output_shape (None, 300)
# ---------------------------------------------------------
# stacking_op: add
# ---------------------------------------------------------
# output: activation: softmax, output_shape: (None, 11), use_bias: False
# loss: categorical_crossentropy
# optimizer: Adam
# ---------------------------------------------------------
#
# Model has been saved to:dt_output/dt_20200906 080322_opnn_nets/opnn_nets.h5
# transform_X cost:13.950277328491211
# transform_y cost:0.007925271987915039
# LGB Val CV= 43.750783801078796
# ####################################################################################################
#
#
# Fold 4
#  rows of train = 175140 rows of holdout = 143298
# 11 class detected, inferred as a [multiclass classification] task
# Preparing features cost:0.09035634994506836
# Imputation cost:0.612128496170044
# Categorical encoding cost:0.3648514747619629
# fit_transform cost:1.1378557682037354
# transform_X cost:13.325381994247437
# transform_y cost:0.007912635803222656
# 1 Physical GPUs, 1 Logical GPUs
# >>>>>>>>>>>>>>>>>>>>>> Model Desc <<<<<<<<<<<<<<<<<<<<<<<
# ---------------------------------------------------------
# inputs:
# ---------------------------------------------------------
# ['all_categorical_vars: (8)', 'input_continuous_all: (80)']
# ---------------------------------------------------------
# embeddings:
# ---------------------------------------------------------
# input_dims: [5, 7, 8, 7, 40, 5, 5, 12]
# output_dims: [20, 20, 20, 20, 20, 20, 20, 20]
# dropout: 0.3
# ---------------------------------------------------------
# dense: dropout: 0
# batch_normalization: False
# ---------------------------------------------------------
# concat_embed_dense: shape: (None, 240)
# ---------------------------------------------------------
# nets: ['opnn_nets']
# ---------------------------------------------------------
# opnn-outer_product: input_shape list(8), output_shape (None, 28)
# opnn-dnn: input_shape (None, 268), output_shape (None, 300)
# ---------------------------------------------------------
# stacking_op: add
# ---------------------------------------------------------
# output: activation: softmax, output_shape: (None, 11), use_bias: False
# loss: categorical_crossentropy
# optimizer: Adam
# ---------------------------------------------------------
#
# Model has been saved to:dt_output/dt_20200906 080716_opnn_nets/opnn_nets.h5
# transform_X cost:13.479987144470215
# transform_y cost:0.008290290832519531
# LGB Val CV= 43.74938905239105
# ####################################################################################################
#
#
# Multi Log Loss Stats 1.45978,0.00093
# 43.803 (0.077)
# CPU times: user 32min 54s, sys: 4min 13s, total: 37min 7s
# Wall time: 25min 49s

# %% [markdown]
# ![](https://github.com/DataCanvasIO/DeepTables/blob/master/docs/source/images/pnn.png)

# %% [markdown]
# ![](https://github.com/DataCanvasIO/DeepTables/raw/master/docs/source/images/pnn.png)

# %% [markdown]
# # Model Building

# %%
nets = 5

dt = [0] * nets

model_dnn = [0] *nets

history = [0] *nets

seeds = [32 ,432, 73]

submission = pd.read_csv('../input/healthcareanalyticsii/sample_submission.csv')

probs = np.zeros(shape=(len(test_df),11))

submission_probs = pd.DataFrame(columns = ['case_id'] + list(le_dict['Stay'].classes_))

submission_probs.iloc[:,0] = submission.iloc[:,0]

submission_probs.iloc[:,1:] = 0

# %%
scores = []

avg_loss = []

submission_name = [] 

X_train_cv,y_train_cv = train_df.copy(), target.copy()

for seed in tnrange(len(seeds)):

    sssf = StratifiedShuffleSplit(n_splits=5, test_size = 0.3 ,random_state=seeds[seed])
    
    for j, (idxT, idxV) in tqdm(enumerate(sssf.split(X_train_cv, y_train_cv))):
        
        print('Fold',j)

        print(' rows of train =',len(idxT),'rows of holdout =',len(idxV))
        
        steps_per_epoch = len(X_train_cv.iloc[idxT])//batch_size
        
        validation_steps = len(X_train_cv.iloc[idxV])//batch_size
        
        K.clear_session()
    
        for i in tnrange(nets):

            dt[i] =  build_model()

            model_dnn[i], history[i] = dt[i].fit(X_train_cv.iloc[idxT], y_train_cv.iloc[idxT],
                                                 validation_data = (X_train_cv.iloc[idxV],y_train_cv.iloc[idxV]),
                                                 steps_per_epoch = steps_per_epoch,
                                                 validation_steps = validation_steps,
                                                 batch_size=batch_size, epochs=epochs, 
                                                 verbose=0, callbacks=[early_stop,annealer])
        
            val_stats = dt[i].evaluate(X_train_cv.iloc[idxV],y_train_cv.iloc[idxV], batch_size=batch_size, verbose=0)
            
            probs_file_name = 'probs_'+str(seeds[seed])+'_'+str(j)+'_'+str(i)+".csv"
            
            submisssion_file_name  = 'submission_'+str(seeds[seed])+'_'+str(j)+'_'+str(i)+".csv"
            
            model_dnn_probs = dt[i].predict_proba(test_df)
            
            submission_probs.iloc[:,1:] = model_dnn_probs
            
            # probablity file per seed per split per tree
            submission_probs.to_csv(probs_file_name,index = False)
            
            submission['Stay'] = le_dict['Stay'].inverse_transform(np.argmax(model_dnn_probs,axis =1))
            
            # submission file per seed per split per tree
            submission.to_csv(submisssion_file_name,index =False)
        
            probs += model_dnn_probs
            
            acc = val_stats['accuracy']*100
            
            scores.append(acc)
            
            avg_loss.append(val_stats['loss'])
            
            submission_name.append(submisssion_file_name)
            
            print('#'*100)
            
            # !rm -rf './dt_output'
            
print("Average Multi Log Loss Stats {0:.5f},{1:.5f}".format(np.array(avg_loss).mean(), np.array(avg_loss).std()))

print('%.3f (%.3f)' % (np.array(scores).mean(), np.array(scores).std()))

# !rm -rf './dt_output'
# Out:
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Fold 0
#  rows of train = 222906 rows of holdout = 95532
# HBox(children=(FloatProgress(value=0.0, max=5.0), HTML(value='')))
# 11 class detected, inferred as a [multiclass classification] task
# Preparing features cost:0.11303400993347168
# Imputation cost:0.7610528469085693
# Categorical encoding cost:0.4823143482208252
# fit_transform cost:1.4542617797851562
# transform_X cost:8.99076223373413
# transform_y cost:0.005446434020996094
# 1 Physical GPUs, 1 Logical GPUs
# >>>>>>>>>>>>>>>>>>>>>> Model Desc <<<<<<<<<<<<<<<<<<<<<<<
# ---------------------------------------------------------
# inputs:
# ---------------------------------------------------------
# ['all_categorical_vars: (8)', 'input_continuous_all: (80)']
# ---------------------------------------------------------
# embeddings:
# ---------------------------------------------------------
# input_dims: [5, 7, 8, 7, 40, 5, 5, 12]
# output_dims: [20, 20, 20, 20, 20, 20, 20, 20]
# dropout: 0.3
# ---------------------------------------------------------
# dense: dropout: 0
# batch_normalization: False
# ---------------------------------------------------------
# concat_embed_dense: shape: (None, 240)
# ---------------------------------------------------------
# nets: ['opnn_nets']
# ---------------------------------------------------------
# opnn-outer_product: input_shape list(8), output_shape (None, 28)
# opnn-dnn: input_shape (None, 268), output_shape (None, 300)
# ---------------------------------------------------------
# stacking_op: add
# ---------------------------------------------------------
# output: activation: softmax, output_shape: (None, 11), use_bias: False
# loss: categorical_crossentropy
# optimizer: Adam
# ---------------------------------------------------------
#
# Model has been saved to:dt_output/dt_20200906 081333_opnn_nets/opnn_nets.h5
# transform_X cost:9.4198477268219
# transform_y cost:0.005666971206665039
# transform_X cost:13.154404401779175
# predict_proba cost:15.047636032104492
# ####################################################################################################
# 11 class detected, inferred as a [multiclass classification] task
# Preparing features cost:0.11360812187194824
# Imputation cost:0.7792418003082275
# Categorical encoding cost:0.47612810134887695
# fit_transform cost:1.4713540077209473
# transform_X cost:9.281746864318848
# transform_y cost:0.006192684173583984
# 1 Physical GPUs, 1 Logical GPUs
# >>>>>>>>>>>>>>>>>>>>>> Model Desc <<<<<<<<<<<<<<<<<<<<<<<
# ---------------------------------------------------------
# inputs:
# ---------------------------------------------------------
# ['all_categorical_vars: (8)', 'input_continuous_all: (80)']
# ---------------------------------------------------------
# embeddings:
# ---------------------------------------------------------
# input_dims: [5, 7, 8, 7, 40, 5, 5, 12]
# output_dims: [20, 20, 20, 20, 20, 20, 20, 20]
# dropout: 0.3
# ---------------------------------------------------------
# dense: dropout: 0
# batch_normalization: False
# ---------------------------------------------------------
# concat_embed_dense: shape: (None, 240)
# ---------------------------------------------------------
# nets: ['opnn_nets']
# ---------------------------------------------------------
# opnn-outer_product: input_shape list(8), output_shape (None, 28)
# opnn-dnn: input_shape (None, 268), output_shape (None, 300)
# ---------------------------------------------------------
# stacking_op: add
# ---------------------------------------------------------
# output: activation: softmax, output_shape: (None, 11), use_bias: False
# loss: categorical_crossentropy
# optimizer: Adam
# ---------------------------------------------------------
#
# Model has been saved to:dt_output/dt_20200906 081907_opnn_nets/opnn_nets.h5
# transform_X cost:9.21665644645691
# transform_y cost:0.005439043045043945
# transform_X cost:12.977742195129395
# predict_proba cost:14.89523458480835
# ####################################################################################################
# 11 class detected, inferred as a [multiclass classification] task
# Preparing features cost:0.16124415397644043
# Imputation cost:0.7649726867675781
# Categorical encoding cost:0.4570953845977783
# fit_transform cost:1.5009238719940186
# transform_X cost:8.978129863739014
# transform_y cost:0.005463600158691406
# 1 Physical GPUs, 1 Logical GPUs
# >>>>>>>>>>>>>>>>>>>>>> Model Desc <<<<<<<<<<<<<<<<<<<<<<<
# ---------------------------------------------------------
# inputs:
# ---------------------------------------------------------
# ['all_categorical_vars: (8)', 'input_continuous_all: (80)']
# ---------------------------------------------------------
# embeddings:
# ---------------------------------------------------------
# input_dims: [5, 7, 8, 7, 40, 5, 5, 12]
# output_dims: [20, 20, 20, 20, 20, 20, 20, 20]
# dropout: 0.3
# ---------------------------------------------------------
# dense: dropout: 0
# batch_normalization: False
# ---------------------------------------------------------
# concat_embed_dense: shape: (None, 240)
# ---------------------------------------------------------
# nets: ['opnn_nets']
# ---------------------------------------------------------
# opnn-outer_product: input_shape list(8), output_shape (None, 28)
# opnn-dnn: input_shape (None, 268), output_shape (None, 300)
# ---------------------------------------------------------
# stacking_op: add
# ---------------------------------------------------------
# output: activation: softmax, output_shape: (None, 11), use_bias: False
# loss: categorical_crossentropy
# optimizer: Adam
# ---------------------------------------------------------
#
# Model has been saved to:dt_output/dt_20200906 082441_opnn_nets/opnn_nets.h5
# transform_X cost:9.599100351333618
# transform_y cost:0.007021903991699219
# transform_X cost:12.906774759292603
# predict_proba cost:15.040953397750854
# ####################################################################################################
# 11 class detected, inferred as a [multiclass classification] task
# Preparing features cost:0.14060449600219727
# Imputation cost:0.7613308429718018
# Categorical encoding cost:0.45574092864990234
# fit_transform cost:1.4602997303009033
# transform_X cost:8.99695634841919
# transform_y cost:0.005680084228515625
# 1 Physical GPUs, 1 Logical GPUs
# >>>>>>>>>>>>>>>>>>>>>> Model Desc <<<<<<<<<<<<<<<<<<<<<<<
# ---------------------------------------------------------
# inputs:
# ---------------------------------------------------------
# ['all_categorical_vars: (8)', 'input_continuous_all: (80)']
# ---------------------------------------------------------
# embeddings:
# ---------------------------------------------------------
# input_dims: [5, 7, 8, 7, 40, 5, 5, 12]
# output_dims: [20, 20, 20, 20, 20, 20, 20, 20]
# dropout: 0.3
# ---------------------------------------------------------
# dense: dropout: 0
# batch_normalization: False
# ---------------------------------------------------------
# concat_embed_dense: shape: (None, 240)
# ---------------------------------------------------------
# nets: ['opnn_nets']
# ---------------------------------------------------------
# opnn-outer_product: input_shape list(8), output_shape (None, 28)
# opnn-dnn: input_shape (None, 268), output_shape (None, 300)
# ---------------------------------------------------------
# stacking_op: add
# ---------------------------------------------------------
# output: activation: softmax, output_shape: (None, 11), use_bias: False
# loss: categorical_crossentropy
# optimizer: Adam
# ---------------------------------------------------------
#
# Model has been saved to:dt_output/dt_20200906 083031_opnn_nets/opnn_nets.h5
# transform_X cost:9.107908964157104
# transform_y cost:0.005571842193603516
# transform_X cost:12.95820164680481
# predict_proba cost:15.485932111740112
# ####################################################################################################
# 11 class detected, inferred as a [multiclass classification] task
# Preparing features cost:0.11325359344482422
# Imputation cost:0.7630136013031006
# Categorical encoding cost:0.46469736099243164
# fit_transform cost:1.4437270164489746
# transform_X cost:9.130698204040527
# transform_y cost:0.005418062210083008
# 1 Physical GPUs, 1 Logical GPUs
# >>>>>>>>>>>>>>>>>>>>>> Model Desc <<<<<<<<<<<<<<<<<<<<<<<
# ---------------------------------------------------------
# inputs:
# ---------------------------------------------------------
# ['all_categorical_vars: (8)', 'input_continuous_all: (80)']
# ---------------------------------------------------------
# embeddings:
# ---------------------------------------------------------
# input_dims: [5, 7, 8, 7, 40, 5, 5, 12]
# output_dims: [20, 20, 20, 20, 20, 20, 20, 20]
# dropout: 0.3
# ---------------------------------------------------------
# dense: dropout: 0
# batch_normalization: False
# ---------------------------------------------------------
# concat_embed_dense: shape: (None, 240)
# ---------------------------------------------------------
# nets: ['opnn_nets']
# ---------------------------------------------------------
# opnn-outer_product: input_shape list(8), output_shape (None, 28)
# opnn-dnn: input_shape (None, 268), output_shape (None, 300)
# ---------------------------------------------------------
# stacking_op: add
# ---------------------------------------------------------
# output: activation: softmax, output_shape: (None, 11), use_bias: False
# loss: categorical_crossentropy
# optimizer: Adam
# ---------------------------------------------------------
#
# Model has been saved to:dt_output/dt_20200906 083614_opnn_nets/opnn_nets.h5
# transform_X cost:8.860256433486938
# transform_y cost:0.005366325378417969
# transform_X cost:13.665905714035034
# predict_proba cost:15.482685089111328
# ####################################################################################################
#
# Fold 1
#  rows of train = 222906 rows of holdout = 95532
# HBox(children=(FloatProgress(value=0.0, max=5.0), HTML(value='')))
# 11 class detected, inferred as a [multiclass classification] task
# Preparing features cost:0.11118769645690918
# Imputation cost:0.7656054496765137
# Categorical encoding cost:0.4576683044433594
# fit_transform cost:1.433312177658081
# transform_X cost:8.976791143417358
# transform_y cost:0.005435943603515625
# 1 Physical GPUs, 1 Logical GPUs
# >>>>>>>>>>>>>>>>>>>>>> Model Desc <<<<<<<<<<<<<<<<<<<<<<<
# ---------------------------------------------------------
# inputs:
# ---------------------------------------------------------
# ['all_categorical_vars: (8)', 'input_continuous_all: (80)']
# ---------------------------------------------------------
# embeddings:
# ---------------------------------------------------------
# input_dims: [5, 7, 8, 7, 40, 5, 5, 12]
# output_dims: [20, 20, 20, 20, 20, 20, 20, 20]
# dropout: 0.3
# ---------------------------------------------------------
# dense: dropout: 0
# batch_normalization: False
# ---------------------------------------------------------
# concat_embed_dense: shape: (None, 240)
# ---------------------------------------------------------
# nets: ['opnn_nets']
# ---------------------------------------------------------
# opnn-outer_product: input_shape list(8), output_shape (None, 28)
# opnn-dnn: input_shape (None, 268), output_shape (None, 300)
# ---------------------------------------------------------
# stacking_op: add
# ---------------------------------------------------------
# output: activation: softmax, output_shape: (None, 11), use_bias: False
# loss: categorical_crossentropy
# optimizer: Adam
# ---------------------------------------------------------
#
# Model has been saved to:dt_output/dt_20200906 084222_opnn_nets/opnn_nets.h5
# transform_X cost:8.883803844451904
# transform_y cost:0.00545048713684082
# transform_X cost:12.653437614440918
# predict_proba cost:14.467780828475952
# ####################################################################################################
# 11 class detected, inferred as a [multiclass classification] task
# Preparing features cost:0.19725346565246582
# Imputation cost:0.7885994911193848
# Categorical encoding cost:0.4743540287017822
# fit_transform cost:1.5829787254333496
# transform_X cost:9.275522947311401
# transform_y cost:0.0067484378814697266
# 1 Physical GPUs, 1 Logical GPUs
# >>>>>>>>>>>>>>>>>>>>>> Model Desc <<<<<<<<<<<<<<<<<<<<<<<
# ---------------------------------------------------------
# inputs:
# ---------------------------------------------------------
# ['all_categorical_vars: (8)', 'input_continuous_all: (80)']
# ---------------------------------------------------------
# embeddings:
# ---------------------------------------------------------
# input_dims: [5, 7, 8, 7, 40, 5, 5, 12]
# output_dims: [20, 20, 20, 20, 20, 20, 20, 20]
# dropout: 0.3
# ---------------------------------------------------------
# dense: dropout: 0
# batch_normalization: False
# ---------------------------------------------------------
# concat_embed_dense: shape: (None, 240)
# ---------------------------------------------------------
# nets: ['opnn_nets']
# ---------------------------------------------------------
# opnn-outer_product: input_shape list(8), output_shape (None, 28)
# opnn-dnn: input_shape (None, 268), output_shape (None, 300)
# ---------------------------------------------------------
# stacking_op: add
# ---------------------------------------------------------
# output: activation: softmax, output_shape: (None, 11), use_bias: False
# loss: categorical_crossentropy
# optimizer: Adam
# ---------------------------------------------------------
#
# Model has been saved to:dt_output/dt_20200906 084656_opnn_nets/opnn_nets.h5
# transform_X cost:8.971746921539307
# transform_y cost:0.005343437194824219
# transform_X cost:13.440816640853882
# predict_proba cost:15.624932527542114
# ####################################################################################################
# 11 class detected, inferred as a [multiclass classification] task
# Preparing features cost:0.1116175651550293
# Imputation cost:0.7708570957183838
# Categorical encoding cost:0.4606952667236328
# fit_transform cost:1.441443681716919
# transform_X cost:8.912882804870605
# transform_y cost:0.0053822994232177734
# 1 Physical GPUs, 1 Logical GPUs
# >>>>>>>>>>>>>>>>>>>>>> Model Desc <<<<<<<<<<<<<<<<<<<<<<<
# ---------------------------------------------------------
# inputs:
# ---------------------------------------------------------
# ['all_categorical_vars: (8)', 'input_continuous_all: (80)']
# ---------------------------------------------------------
# embeddings:
# ---------------------------------------------------------
# input_dims: [5, 7, 8, 7, 40, 5, 5, 12]
# output_dims: [20, 20, 20, 20, 20, 20, 20, 20]
# dropout: 0.3
# ---------------------------------------------------------
# dense: dropout: 0
# batch_normalization: False
# ---------------------------------------------------------
# concat_embed_dense: shape: (None, 240)
# ---------------------------------------------------------
# nets: ['opnn_nets']
# ---------------------------------------------------------
# opnn-outer_product: input_shape list(8), output_shape (None, 28)
# opnn-dnn: input_shape (None, 268), output_shape (None, 300)
# ---------------------------------------------------------
# stacking_op: add
# ---------------------------------------------------------
# output: activation: softmax, output_shape: (None, 11), use_bias: False
# loss: categorical_crossentropy
# optimizer: Adam
# ---------------------------------------------------------
#
# Model has been saved to:dt_output/dt_20200906 085316_opnn_nets/opnn_nets.h5
# transform_X cost:8.92181396484375
# transform_y cost:0.005310535430908203
# transform_X cost:13.098793268203735
# predict_proba cost:14.972455501556396
# ####################################################################################################
# 11 class detected, inferred as a [multiclass classification] task
# Preparing features cost:0.11707639694213867
# Imputation cost:0.8109526634216309
# Categorical encoding cost:0.4640176296234131
# fit_transform cost:1.4935541152954102
# transform_X cost:9.310312509536743
# transform_y cost:0.0054738521575927734
# 1 Physical GPUs, 1 Logical GPUs
# >>>>>>>>>>>>>>>>>>>>>> Model Desc <<<<<<<<<<<<<<<<<<<<<<<
# ---------------------------------------------------------
# inputs:
# ---------------------------------------------------------
# ['all_categorical_vars: (8)', 'input_continuous_all: (80)']
# ---------------------------------------------------------
# embeddings:
# ---------------------------------------------------------
# input_dims: [5, 7, 8, 7, 40, 5, 5, 12]
# output_dims: [20, 20, 20, 20, 20, 20, 20, 20]
# dropout: 0.3
# ---------------------------------------------------------
# dense: dropout: 0
# batch_normalization: False
# ---------------------------------------------------------
# concat_embed_dense: shape: (None, 240)
# ---------------------------------------------------------
# nets: ['opnn_nets']
# ---------------------------------------------------------
# opnn-outer_product: input_shape list(8), output_shape (None, 28)
# opnn-dnn: input_shape (None, 268), output_shape (None, 300)
# ---------------------------------------------------------
# stacking_op: add
# ---------------------------------------------------------
# output: activation: softmax, output_shape: (None, 11), use_bias: False
# loss: categorical_crossentropy
# optimizer: Adam
# ---------------------------------------------------------
#
# Model has been saved to:dt_output/dt_20200906 085803_opnn_nets/opnn_nets.h5
# transform_X cost:8.901384115219116
# transform_y cost:0.0055201053619384766
# transform_X cost:12.793635129928589
# predict_proba cost:14.608047008514404
# ####################################################################################################
# 11 class detected, inferred as a [multiclass classification] task
# Preparing features cost:0.11186814308166504
# Imputation cost:0.8432941436767578
# Categorical encoding cost:0.49095940589904785
# fit_transform cost:1.5452666282653809
# transform_X cost:8.981906414031982
# transform_y cost:0.005252838134765625
# 1 Physical GPUs, 1 Logical GPUs
# >>>>>>>>>>>>>>>>>>>>>> Model Desc <<<<<<<<<<<<<<<<<<<<<<<
# ---------------------------------------------------------
# inputs:
# ---------------------------------------------------------
# ['all_categorical_vars: (8)', 'input_continuous_all: (80)']
# ---------------------------------------------------------
# embeddings:
# ---------------------------------------------------------
# input_dims: [5, 7, 8, 7, 40, 5, 5, 12]
# output_dims: [20, 20, 20, 20, 20, 20, 20, 20]
# dropout: 0.3
# ---------------------------------------------------------
# dense: dropout: 0
# batch_normalization: False
# ---------------------------------------------------------
# concat_embed_dense: shape: (None, 240)
# ---------------------------------------------------------
# nets: ['opnn_nets']
# ---------------------------------------------------------
# opnn-outer_product: input_shape list(8), output_shape (None, 28)
# opnn-dnn: input_shape (None, 268), output_shape (None, 300)
# ---------------------------------------------------------
# stacking_op: add
# ---------------------------------------------------------
# output: activation: softmax, output_shape: (None, 11), use_bias: False
# loss: categorical_crossentropy
# optimizer: Adam
# ---------------------------------------------------------
#
# Model has been saved to:dt_output/dt_20200906 090253_opnn_nets/opnn_nets.h5
# transform_X cost:8.732502222061157
# transform_y cost:0.005504131317138672
# transform_X cost:13.391655683517456
# predict_proba cost:15.242741346359253
# ####################################################################################################
#
# Fold 2
#  rows of train = 222906 rows of holdout = 95532
# HBox(children=(FloatProgress(value=0.0, max=5.0), HTML(value='')))
# 11 class detected, inferred as a [multiclass classification] task
# Preparing features cost:0.19524073600769043
# Imputation cost:0.8499336242675781
# Categorical encoding cost:0.46187257766723633
# fit_transform cost:1.634718418121338
# transform_X cost:8.966265201568604
# transform_y cost:0.005646467208862305
# 1 Physical GPUs, 1 Logical GPUs
# >>>>>>>>>>>>>>>>>>>>>> Model Desc <<<<<<<<<<<<<<<<<<<<<<<
# ---------------------------------------------------------
# inputs:
# ---------------------------------------------------------
# ['all_categorical_vars: (8)', 'input_continuous_all: (80)']
# ---------------------------------------------------------
# embeddings:
# ---------------------------------------------------------
# input_dims: [5, 7, 8, 7, 40, 5, 5, 12]
# output_dims: [20, 20, 20, 20, 20, 20, 20, 20]
# dropout: 0.3
# ---------------------------------------------------------
# dense: dropout: 0
# batch_normalization: False
# ---------------------------------------------------------
# concat_embed_dense: shape: (None, 240)
# ---------------------------------------------------------
# nets: ['opnn_nets']
# ---------------------------------------------------------
# opnn-outer_product: input_shape list(8), output_shape (None, 28)
# opnn-dnn: input_shape (None, 268), output_shape (None, 300)
# ---------------------------------------------------------
# stacking_op: add
# ---------------------------------------------------------
# output: activation: softmax, output_shape: (None, 11), use_bias: False
# loss: categorical_crossentropy
# optimizer: Adam
# ---------------------------------------------------------
#
# Model has been saved to:dt_output/dt_20200906 090823_opnn_nets/opnn_nets.h5
# transform_X cost:9.350925207138062
# transform_y cost:0.005776166915893555
# transform_X cost:12.825282096862793
# predict_proba cost:14.645873308181763
# ####################################################################################################
# 11 class detected, inferred as a [multiclass classification] task
# Preparing features cost:0.132066011428833
# Imputation cost:0.7852573394775391
# Categorical encoding cost:0.508281946182251
# fit_transform cost:1.5292487144470215
# transform_X cost:8.952922344207764
# transform_y cost:0.0054666996002197266
# 1 Physical GPUs, 1 Logical GPUs
# >>>>>>>>>>>>>>>>>>>>>> Model Desc <<<<<<<<<<<<<<<<<<<<<<<
# ---------------------------------------------------------
# inputs:
# ---------------------------------------------------------
# ['all_categorical_vars: (8)', 'input_continuous_all: (80)']
# ---------------------------------------------------------
# embeddings:
# ---------------------------------------------------------
# input_dims: [5, 7, 8, 7, 40, 5, 5, 12]
# output_dims: [20, 20, 20, 20, 20, 20, 20, 20]
# dropout: 0.3
# ---------------------------------------------------------
# dense: dropout: 0
# batch_normalization: False
# ---------------------------------------------------------
# concat_embed_dense: shape: (None, 240)
# ---------------------------------------------------------
# nets: ['opnn_nets']
# ---------------------------------------------------------
# opnn-outer_product: input_shape list(8), output_shape (None, 28)
# opnn-dnn: input_shape (None, 268), output_shape (None, 300)
# ---------------------------------------------------------
# stacking_op: add
# ---------------------------------------------------------
# output: activation: softmax, output_shape: (None, 11), use_bias: False
# loss: categorical_crossentropy
# optimizer: Adam
# ---------------------------------------------------------
#
# Model has been saved to:dt_output/dt_20200906 091435_opnn_nets/opnn_nets.h5
# transform_X cost:9.249812841415405
# transform_y cost:0.005591154098510742
# transform_X cost:13.228623628616333
# predict_proba cost:15.099841117858887
# ####################################################################################################
# 11 class detected, inferred as a [multiclass classification] task
# Preparing features cost:0.11804533004760742
# Imputation cost:1.010789394378662
# Categorical encoding cost:0.4850890636444092
# fit_transform cost:1.7164819240570068
# transform_X cost:9.854573011398315
# transform_y cost:0.0053250789642333984
# 1 Physical GPUs, 1 Logical GPUs
# >>>>>>>>>>>>>>>>>>>>>> Model Desc <<<<<<<<<<<<<<<<<<<<<<<
# ---------------------------------------------------------
# inputs:
# ---------------------------------------------------------
# ['all_categorical_vars: (8)', 'input_continuous_all: (80)']
# ---------------------------------------------------------
# embeddings:
# ---------------------------------------------------------
# input_dims: [5, 7, 8, 7, 40, 5, 5, 12]
# output_dims: [20, 20, 20, 20, 20, 20, 20, 20]
# dropout: 0.3
# ---------------------------------------------------------
# dense: dropout: 0
# batch_normalization: False
# ---------------------------------------------------------
# concat_embed_dense: shape: (None, 240)
# ---------------------------------------------------------
# nets: ['opnn_nets']
# ---------------------------------------------------------
# opnn-outer_product: input_shape list(8), output_shape (None, 28)
# opnn-dnn: input_shape (None, 268), output_shape (None, 300)
# ---------------------------------------------------------
# stacking_op: add
# ---------------------------------------------------------
# output: activation: softmax, output_shape: (None, 11), use_bias: False
# loss: categorical_crossentropy
# optimizer: Adam
# ---------------------------------------------------------
#
# Model has been saved to:dt_output/dt_20200906 091902_opnn_nets/opnn_nets.h5
# transform_X cost:9.172055006027222
# transform_y cost:0.00545048713684082
# transform_X cost:12.96955156326294
# predict_proba cost:14.812349081039429
# ####################################################################################################
# 11 class detected, inferred as a [multiclass classification] task
# Preparing features cost:0.1316983699798584
# Imputation cost:0.8891046047210693
# Categorical encoding cost:0.4997110366821289
# fit_transform cost:1.6174490451812744
# transform_X cost:9.434357643127441
# transform_y cost:0.005457401275634766
# 1 Physical GPUs, 1 Logical GPUs
# >>>>>>>>>>>>>>>>>>>>>> Model Desc <<<<<<<<<<<<<<<<<<<<<<<
# ---------------------------------------------------------
# inputs:
# ---------------------------------------------------------
# ['all_categorical_vars: (8)', 'input_continuous_all: (80)']
# ---------------------------------------------------------
# embeddings:
# ---------------------------------------------------------
# input_dims: [5, 7, 8, 7, 40, 5, 5, 12]
# output_dims: [20, 20, 20, 20, 20, 20, 20, 20]
# dropout: 0.3
# ---------------------------------------------------------
# dense: dropout: 0
# batch_normalization: False
# ---------------------------------------------------------
# concat_embed_dense: shape: (None, 240)
# ---------------------------------------------------------
# nets: ['opnn_nets']
# ---------------------------------------------------------
# opnn-outer_product: input_shape list(8), output_shape (None, 28)
# opnn-dnn: input_shape (None, 268), output_shape (None, 300)
# ---------------------------------------------------------
# stacking_op: add
# ---------------------------------------------------------
# output: activation: softmax, output_shape: (None, 11), use_bias: False
# loss: categorical_crossentropy
# optimizer: Adam
# ---------------------------------------------------------
#
# Model has been saved to:dt_output/dt_20200906 092604_opnn_nets/opnn_nets.h5
# transform_X cost:8.827770471572876
# transform_y cost:0.005530118942260742
# transform_X cost:13.164056301116943
# predict_proba cost:14.998290300369263
# ####################################################################################################
# 11 class detected, inferred as a [multiclass classification] task
# Preparing features cost:0.11092972755432129
# Imputation cost:1.044210433959961
# Categorical encoding cost:0.46207666397094727
# fit_transform cost:1.7143287658691406
# transform_X cost:9.402414321899414
# transform_y cost:0.0056896209716796875
# 1 Physical GPUs, 1 Logical GPUs
# >>>>>>>>>>>>>>>>>>>>>> Model Desc <<<<<<<<<<<<<<<<<<<<<<<
# ---------------------------------------------------------
# inputs:
# ---------------------------------------------------------
# ['all_categorical_vars: (8)', 'input_continuous_all: (80)']
# ---------------------------------------------------------
# embeddings:
# ---------------------------------------------------------
# input_dims: [5, 7, 8, 7, 40, 5, 5, 12]
# output_dims: [20, 20, 20, 20, 20, 20, 20, 20]
# dropout: 0.3
# ---------------------------------------------------------
# dense: dropout: 0
# batch_normalization: False
# ---------------------------------------------------------
# concat_embed_dense: shape: (None, 240)
# ---------------------------------------------------------
# nets: ['opnn_nets']
# ---------------------------------------------------------
# opnn-outer_product: input_shape list(8), output_shape (None, 28)
# opnn-dnn: input_shape (None, 268), output_shape (None, 300)
# ---------------------------------------------------------
# stacking_op: add
# ---------------------------------------------------------
# output: activation: softmax, output_shape: (None, 11), use_bias: False
# loss: categorical_crossentropy
# optimizer: Adam
# ---------------------------------------------------------
#
# Model has been saved to:dt_output/dt_20200906 093104_opnn_nets/opnn_nets.h5
# transform_X cost:9.002026081085205
# transform_y cost:0.005326032638549805
# transform_X cost:13.028927326202393
# predict_proba cost:14.992984533309937
# ####################################################################################################
#
# Fold 3
#  rows of train = 222906 rows of holdout = 95532
# HBox(children=(FloatProgress(value=0.0, max=5.0), HTML(value='')))
# 11 class detected, inferred as a [multiclass classification] task
# Preparing features cost:0.12262892723083496
# Imputation cost:0.7530624866485596
# Categorical encoding cost:0.45822954177856445
# fit_transform cost:1.4322929382324219
# transform_X cost:9.350189208984375
# transform_y cost:0.0053637027740478516
# 1 Physical GPUs, 1 Logical GPUs
# >>>>>>>>>>>>>>>>>>>>>> Model Desc <<<<<<<<<<<<<<<<<<<<<<<
# ---------------------------------------------------------
# inputs:
# ---------------------------------------------------------
# ['all_categorical_vars: (8)', 'input_continuous_all: (80)']
# ---------------------------------------------------------
# embeddings:
# ---------------------------------------------------------
# input_dims: [5, 7, 8, 7, 40, 5, 5, 12]
# output_dims: [20, 20, 20, 20, 20, 20, 20, 20]
# dropout: 0.3
# ---------------------------------------------------------
# dense: dropout: 0
# batch_normalization: False
# ---------------------------------------------------------
# concat_embed_dense: shape: (None, 240)
# ---------------------------------------------------------
# nets: ['opnn_nets']
# ---------------------------------------------------------
# opnn-outer_product: input_shape list(8), output_shape (None, 28)
# opnn-dnn: input_shape (None, 268), output_shape (None, 300)
# ---------------------------------------------------------
# stacking_op: add
# ---------------------------------------------------------
# output: activation: softmax, output_shape: (None, 11), use_bias: False
# loss: categorical_crossentropy
# optimizer: Adam
# ---------------------------------------------------------
#
# Model has been saved to:dt_output/dt_20200906 093653_opnn_nets/opnn_nets.h5
# transform_X cost:9.043920755386353
# transform_y cost:0.005454301834106445
# transform_X cost:13.22986364364624
# predict_proba cost:15.109153747558594
# ####################################################################################################
# 11 class detected, inferred as a [multiclass classification] task
# Preparing features cost:0.11490702629089355
# Imputation cost:0.76883864402771
# Categorical encoding cost:0.459503173828125
# fit_transform cost:1.446434497833252
# transform_X cost:9.230324983596802
# transform_y cost:0.005480766296386719
# 1 Physical GPUs, 1 Logical GPUs
# >>>>>>>>>>>>>>>>>>>>>> Model Desc <<<<<<<<<<<<<<<<<<<<<<<
# ---------------------------------------------------------
# inputs:
# ---------------------------------------------------------
# ['all_categorical_vars: (8)', 'input_continuous_all: (80)']
# ---------------------------------------------------------
# embeddings:
# ---------------------------------------------------------
# input_dims: [5, 7, 8, 7, 40, 5, 5, 12]
# output_dims: [20, 20, 20, 20, 20, 20, 20, 20]
# dropout: 0.3
# ---------------------------------------------------------
# dense: dropout: 0
# batch_normalization: False
# ---------------------------------------------------------
# concat_embed_dense: shape: (None, 240)
# ---------------------------------------------------------
# nets: ['opnn_nets']
# ---------------------------------------------------------
# opnn-outer_product: input_shape list(8), output_shape (None, 28)
# opnn-dnn: input_shape (None, 268), output_shape (None, 300)
# ---------------------------------------------------------
# stacking_op: add
# ---------------------------------------------------------
# output: activation: softmax, output_shape: (None, 11), use_bias: False
# loss: categorical_crossentropy
# optimizer: Adam
# ---------------------------------------------------------
#
# Model has been saved to:dt_output/dt_20200906 094339_opnn_nets/opnn_nets.h5
# transform_X cost:8.920864582061768
# transform_y cost:0.005469322204589844
# transform_X cost:13.366466045379639
# predict_proba cost:15.4815194606781
# ####################################################################################################
# 11 class detected, inferred as a [multiclass classification] task
# Preparing features cost:0.1115884780883789
# Imputation cost:0.7538812160491943
# Categorical encoding cost:0.46736979484558105
# fit_transform cost:1.4326057434082031
# transform_X cost:8.819047927856445
# transform_y cost:0.005530595779418945
# 1 Physical GPUs, 1 Logical GPUs
# >>>>>>>>>>>>>>>>>>>>>> Model Desc <<<<<<<<<<<<<<<<<<<<<<<
# ---------------------------------------------------------
# inputs:
# ---------------------------------------------------------
# ['all_categorical_vars: (8)', 'input_continuous_all: (80)']
# ---------------------------------------------------------
# embeddings:
# ---------------------------------------------------------
# input_dims: [5, 7, 8, 7, 40, 5, 5, 12]
# output_dims: [20, 20, 20, 20, 20, 20, 20, 20]
# dropout: 0.3
# ---------------------------------------------------------
# dense: dropout: 0
# batch_normalization: False
# ---------------------------------------------------------
# concat_embed_dense: shape: (None, 240)
# ---------------------------------------------------------
# nets: ['opnn_nets']
# ---------------------------------------------------------
# opnn-outer_product: input_shape list(8), output_shape (None, 28)
# opnn-dnn: input_shape (None, 268), output_shape (None, 300)
# ---------------------------------------------------------
# stacking_op: add
# ---------------------------------------------------------
# output: activation: softmax, output_shape: (None, 11), use_bias: False
# loss: categorical_crossentropy
# optimizer: Adam
# ---------------------------------------------------------
#
# Model has been saved to:dt_output/dt_20200906 095016_opnn_nets/opnn_nets.h5
# transform_X cost:8.918721437454224
# transform_y cost:0.005418539047241211
# transform_X cost:12.860533237457275
# predict_proba cost:14.66941237449646
# ####################################################################################################
# 11 class detected, inferred as a [multiclass classification] task
# Preparing features cost:0.11184406280517578
# Imputation cost:0.8437089920043945
# Categorical encoding cost:0.46397972106933594
# fit_transform cost:1.5207114219665527
# transform_X cost:8.964423418045044
# transform_y cost:0.0054225921630859375
# 1 Physical GPUs, 1 Logical GPUs
# >>>>>>>>>>>>>>>>>>>>>> Model Desc <<<<<<<<<<<<<<<<<<<<<<<
# ---------------------------------------------------------
# inputs:
# ---------------------------------------------------------
# ['all_categorical_vars: (8)', 'input_continuous_all: (80)']
# ---------------------------------------------------------
# embeddings:
# ---------------------------------------------------------
# input_dims: [5, 7, 8, 7, 40, 5, 5, 12]
# output_dims: [20, 20, 20, 20, 20, 20, 20, 20]
# dropout: 0.3
# ---------------------------------------------------------
# dense: dropout: 0
# batch_normalization: False
# ---------------------------------------------------------
# concat_embed_dense: shape: (None, 240)
# ---------------------------------------------------------
# nets: ['opnn_nets']
# ---------------------------------------------------------
# opnn-outer_product: input_shape list(8), output_shape (None, 28)
# opnn-dnn: input_shape (None, 268), output_shape (None, 300)
# ---------------------------------------------------------
# stacking_op: add
# ---------------------------------------------------------
# output: activation: softmax, output_shape: (None, 11), use_bias: False
# loss: categorical_crossentropy
# optimizer: Adam
# ---------------------------------------------------------
#
# Model has been saved to:dt_output/dt_20200906 095545_opnn_nets/opnn_nets.h5
# transform_X cost:8.907841444015503
# transform_y cost:0.006603717803955078
# transform_X cost:12.822848320007324
# predict_proba cost:14.969534635543823
# ####################################################################################################
# 11 class detected, inferred as a [multiclass classification] task
# Preparing features cost:0.12046003341674805
# Imputation cost:0.9162082672119141
# Categorical encoding cost:0.5191380977630615
# fit_transform cost:1.655385971069336
# transform_X cost:9.377080917358398
# transform_y cost:0.005406379699707031
# 1 Physical GPUs, 1 Logical GPUs
# >>>>>>>>>>>>>>>>>>>>>> Model Desc <<<<<<<<<<<<<<<<<<<<<<<
# ---------------------------------------------------------
# inputs:
# ---------------------------------------------------------
# ['all_categorical_vars: (8)', 'input_continuous_all: (80)']
# ---------------------------------------------------------
# embeddings:
# ---------------------------------------------------------
# input_dims: [5, 7, 8, 7, 40, 5, 5, 12]
# output_dims: [20, 20, 20, 20, 20, 20, 20, 20]
# dropout: 0.3
# ---------------------------------------------------------
# dense: dropout: 0
# batch_normalization: False
# ---------------------------------------------------------
# concat_embed_dense: shape: (None, 240)
# ---------------------------------------------------------
# nets: ['opnn_nets']
# ---------------------------------------------------------
# opnn-outer_product: input_shape list(8), output_shape (None, 28)
# opnn-dnn: input_shape (None, 268), output_shape (None, 300)
# ---------------------------------------------------------
# stacking_op: add
# ---------------------------------------------------------
# output: activation: softmax, output_shape: (None, 11), use_bias: False
# loss: categorical_crossentropy
# optimizer: Adam
# ---------------------------------------------------------
#
# Model has been saved to:dt_output/dt_20200906 100201_opnn_nets/opnn_nets.h5
# transform_X cost:9.361781597137451
# transform_y cost:0.005383014678955078
# transform_X cost:12.99419093132019
# predict_proba cost:14.854065656661987
# ####################################################################################################
#
# Fold 4
#  rows of train = 222906 rows of holdout = 95532
# HBox(children=(FloatProgress(value=0.0, max=5.0), HTML(value='')))
# 11 class detected, inferred as a [multiclass classification] task
# Preparing features cost:0.11236739158630371
# Imputation cost:0.8243124485015869
# Categorical encoding cost:0.5021142959594727
# fit_transform cost:1.5357451438903809
# transform_X cost:8.947556972503662
# transform_y cost:0.006128072738647461
# 1 Physical GPUs, 1 Logical GPUs
# >>>>>>>>>>>>>>>>>>>>>> Model Desc <<<<<<<<<<<<<<<<<<<<<<<
# ---------------------------------------------------------
# inputs:
# ---------------------------------------------------------
# ['all_categorical_vars: (8)', 'input_continuous_all: (80)']
# ---------------------------------------------------------
# embeddings:
# ---------------------------------------------------------
# input_dims: [5, 7, 8, 7, 40, 5, 5, 12]
# output_dims: [20, 20, 20, 20, 20, 20, 20, 20]
# dropout: 0.3
# ---------------------------------------------------------
# dense: dropout: 0
# batch_normalization: False
# ---------------------------------------------------------
# concat_embed_dense: shape: (None, 240)
# ---------------------------------------------------------
# nets: ['opnn_nets']
# ---------------------------------------------------------
# opnn-outer_product: input_shape list(8), output_shape (None, 28)
# opnn-dnn: input_shape (None, 268), output_shape (None, 300)
# ---------------------------------------------------------
# stacking_op: add
# ---------------------------------------------------------
# output: activation: softmax, output_shape: (None, 11), use_bias: False
# loss: categorical_crossentropy
# optimizer: Adam
# ---------------------------------------------------------
#
# Model has been saved to:dt_output/dt_20200906 100726_opnn_nets/opnn_nets.h5
# transform_X cost:9.187433004379272
# transform_y cost:0.005280733108520508
# transform_X cost:12.611870527267456
# predict_proba cost:14.456528186798096
# ####################################################################################################
# 11 class detected, inferred as a [multiclass classification] task
# Preparing features cost:0.11266303062438965
# Imputation cost:0.8990788459777832
# Categorical encoding cost:0.4713103771209717
# fit_transform cost:1.5822601318359375
# transform_X cost:8.996441841125488
# transform_y cost:0.005310773849487305
# 1 Physical GPUs, 1 Logical GPUs
# >>>>>>>>>>>>>>>>>>>>>> Model Desc <<<<<<<<<<<<<<<<<<<<<<<
# ---------------------------------------------------------
# inputs:
# ---------------------------------------------------------
# ['all_categorical_vars: (8)', 'input_continuous_all: (80)']
# ---------------------------------------------------------
# embeddings:
# ---------------------------------------------------------
# input_dims: [5, 7, 8, 7, 40, 5, 5, 12]
# output_dims: [20, 20, 20, 20, 20, 20, 20, 20]
# dropout: 0.3
# ---------------------------------------------------------
# dense: dropout: 0
# batch_normalization: False
# ---------------------------------------------------------
# concat_embed_dense: shape: (None, 240)
# ---------------------------------------------------------
# nets: ['opnn_nets']
# ---------------------------------------------------------
# opnn-outer_product: input_shape list(8), output_shape (None, 28)
# opnn-dnn: input_shape (None, 268), output_shape (None, 300)
# ---------------------------------------------------------
# stacking_op: add
# ---------------------------------------------------------
# output: activation: softmax, output_shape: (None, 11), use_bias: False
# loss: categorical_crossentropy
# optimizer: Adam
# ---------------------------------------------------------
#
# Model has been saved to:dt_output/dt_20200906 101340_opnn_nets/opnn_nets.h5
# transform_X cost:9.033142805099487
# transform_y cost:0.005373954772949219
# transform_X cost:12.807876110076904
# predict_proba cost:14.656361818313599
# ####################################################################################################
# 11 class detected, inferred as a [multiclass classification] task
# Preparing features cost:0.11356854438781738
# Imputation cost:0.8563668727874756
# Categorical encoding cost:0.4545576572418213
# fit_transform cost:1.5250837802886963
# transform_X cost:8.933210611343384
# transform_y cost:0.005307435989379883
# 1 Physical GPUs, 1 Logical GPUs
# >>>>>>>>>>>>>>>>>>>>>> Model Desc <<<<<<<<<<<<<<<<<<<<<<<
# ---------------------------------------------------------
# inputs:
# ---------------------------------------------------------
# ['all_categorical_vars: (8)', 'input_continuous_all: (80)']
# ---------------------------------------------------------
# embeddings:
# ---------------------------------------------------------
# input_dims: [5, 7, 8, 7, 40, 5, 5, 12]
# output_dims: [20, 20, 20, 20, 20, 20, 20, 20]
# dropout: 0.3
# ---------------------------------------------------------
# dense: dropout: 0
# batch_normalization: False
# ---------------------------------------------------------
# concat_embed_dense: shape: (None, 240)
# ---------------------------------------------------------
# nets: ['opnn_nets']
# ---------------------------------------------------------
# opnn-outer_product: input_shape list(8), output_shape (None, 28)
# opnn-dnn: input_shape (None, 268), output_shape (None, 300)
# ---------------------------------------------------------
# stacking_op: add
# ---------------------------------------------------------
# output: activation: softmax, output_shape: (None, 11), use_bias: False
# loss: categorical_crossentropy
# optimizer: Adam
# ---------------------------------------------------------
#
# Model has been saved to:dt_output/dt_20200906 101945_opnn_nets/opnn_nets.h5
# transform_X cost:9.038499116897583
# transform_y cost:0.005376338958740234
# transform_X cost:13.012526035308838
# predict_proba cost:15.257246732711792
# ####################################################################################################
# 11 class detected, inferred as a [multiclass classification] task
# Preparing features cost:0.11842703819274902
# Imputation cost:0.768071174621582
# Categorical encoding cost:0.477294921875
# fit_transform cost:1.4632682800292969
# transform_X cost:8.983997821807861
# transform_y cost:0.005450248718261719
# 1 Physical GPUs, 1 Logical GPUs
# >>>>>>>>>>>>>>>>>>>>>> Model Desc <<<<<<<<<<<<<<<<<<<<<<<
# ---------------------------------------------------------
# inputs:
# ---------------------------------------------------------
# ['all_categorical_vars: (8)', 'input_continuous_all: (80)']
# ---------------------------------------------------------
# embeddings:
# ---------------------------------------------------------
# input_dims: [5, 7, 8, 7, 40, 5, 5, 12]
# output_dims: [20, 20, 20, 20, 20, 20, 20, 20]
# dropout: 0.3
# ---------------------------------------------------------
# dense: dropout: 0
# batch_normalization: False
# ---------------------------------------------------------
# concat_embed_dense: shape: (None, 240)
# ---------------------------------------------------------
# nets: ['opnn_nets']
# ---------------------------------------------------------
# opnn-outer_product: input_shape list(8), output_shape (None, 28)
# opnn-dnn: input_shape (None, 268), output_shape (None, 300)
# ---------------------------------------------------------
# stacking_op: add
# ---------------------------------------------------------
# output: activation: softmax, output_shape: (None, 11), use_bias: False
# loss: categorical_crossentropy
# optimizer: Adam
# ---------------------------------------------------------
#
# Model has been saved to:dt_output/dt_20200906 102515_opnn_nets/opnn_nets.h5
# transform_X cost:8.92602014541626
# transform_y cost:0.0054776668548583984
# transform_X cost:12.851717710494995
# predict_proba cost:14.876298427581787
# ####################################################################################################
# 11 class detected, inferred as a [multiclass classification] task
# Preparing features cost:0.11919689178466797
# Imputation cost:0.8022193908691406
# Categorical encoding cost:0.45873165130615234
# fit_transform cost:1.4781200885772705
# transform_X cost:9.118307113647461
# transform_y cost:0.005404472351074219
# 1 Physical GPUs, 1 Logical GPUs
# >>>>>>>>>>>>>>>>>>>>>> Model Desc <<<<<<<<<<<<<<<<<<<<<<<
# ---------------------------------------------------------
# inputs:
# ---------------------------------------------------------
# ['all_categorical_vars: (8)', 'input_continuous_all: (80)']
# ---------------------------------------------------------
# embeddings:
# ---------------------------------------------------------
# input_dims: [5, 7, 8, 7, 40, 5, 5, 12]
# output_dims: [20, 20, 20, 20, 20, 20, 20, 20]
# dropout: 0.3
# ---------------------------------------------------------
# dense: dropout: 0
# batch_normalization: False
# ---------------------------------------------------------
# concat_embed_dense: shape: (None, 240)
# ---------------------------------------------------------
# nets: ['opnn_nets']
# ---------------------------------------------------------
# opnn-outer_product: input_shape list(8), output_shape (None, 28)
# opnn-dnn: input_shape (None, 268), output_shape (None, 300)
# ---------------------------------------------------------
# stacking_op: add
# ---------------------------------------------------------
# output: activation: softmax, output_shape: (None, 11), use_bias: False
# loss: categorical_crossentropy
# optimizer: Adam
# ---------------------------------------------------------
#
# Model has been saved to:dt_output/dt_20200906 103207_opnn_nets/opnn_nets.h5
# transform_X cost:8.971313953399658
# transform_y cost:0.005290985107421875
# ...
# ---------------------------------------------------------
# stacking_op: add
# ---------------------------------------------------------
# output: activation: softmax, output_shape: (None, 11), use_bias: False
# loss: categorical_crossentropy
# optimizer: Adam
# ---------------------------------------------------------
#
# Model has been saved to:dt_output/dt_20200906 144707_opnn_nets/opnn_nets.h5
# transform_X cost:9.024860143661499
# transform_y cost:0.005391597747802734
# transform_X cost:12.803187847137451
# predict_proba cost:14.670365571975708
# ####################################################################################################
# 11 class detected, inferred as a [multiclass classification] task
# Preparing features cost:0.21985936164855957
# Imputation cost:0.9442636966705322
# Categorical encoding cost:0.4615354537963867
# fit_transform cost:1.7354707717895508
# transform_X cost:9.50801944732666
# transform_y cost:0.006691932678222656
# 1 Physical GPUs, 1 Logical GPUs
# >>>>>>>>>>>>>>>>>>>>>> Model Desc <<<<<<<<<<<<<<<<<<<<<<<
# ---------------------------------------------------------
# inputs:
# ---------------------------------------------------------
# ['all_categorical_vars: (8)', 'input_continuous_all: (80)']
# ---------------------------------------------------------
# embeddings:
# ---------------------------------------------------------
# input_dims: [5, 7, 8, 7, 40, 5, 5, 12]
# output_dims: [20, 20, 20, 20, 20, 20, 20, 20]
# dropout: 0.3
# ---------------------------------------------------------
# dense: dropout: 0
# batch_normalization: False
# ---------------------------------------------------------
# concat_embed_dense: shape: (None, 240)
# ---------------------------------------------------------
# nets: ['opnn_nets']
# ---------------------------------------------------------
# opnn-outer_product: input_shape list(8), output_shape (None, 28)
# opnn-dnn: input_shape (None, 268), output_shape (None, 300)
# ---------------------------------------------------------
# stacking_op: add
# ---------------------------------------------------------
# output: activation: softmax, output_shape: (None, 11), use_bias: False
# loss: categorical_crossentropy
# optimizer: Adam
# ---------------------------------------------------------
#
# Model has been saved to:dt_output/dt_20200906 145202_opnn_nets/opnn_nets.h5
# transform_X cost:8.920026779174805
# transform_y cost:0.005305290222167969
# transform_X cost:12.720237255096436
# predict_proba cost:14.577258825302124
# ####################################################################################################
# 11 class detected, inferred as a [multiclass classification] task
# Preparing features cost:0.11735224723815918
# Imputation cost:0.8467063903808594
# Categorical encoding cost:0.49764323234558105
# fit_transform cost:1.5583665370941162
# transform_X cost:9.476575136184692
# transform_y cost:0.007523536682128906
# 1 Physical GPUs, 1 Logical GPUs
# >>>>>>>>>>>>>>>>>>>>>> Model Desc <<<<<<<<<<<<<<<<<<<<<<<
# ---------------------------------------------------------
# inputs:
# ---------------------------------------------------------
# ['all_categorical_vars: (8)', 'input_continuous_all: (80)']
# ---------------------------------------------------------
# embeddings:
# ---------------------------------------------------------
# input_dims: [5, 7, 8, 7, 40, 5, 5, 12]
# output_dims: [20, 20, 20, 20, 20, 20, 20, 20]
# dropout: 0.3
# ---------------------------------------------------------
# dense: dropout: 0
# batch_normalization: False
# ---------------------------------------------------------
# concat_embed_dense: shape: (None, 240)
# ---------------------------------------------------------
# nets: ['opnn_nets']
# ---------------------------------------------------------
# opnn-outer_product: input_shape list(8), output_shape (None, 28)
# opnn-dnn: input_shape (None, 268), output_shape (None, 300)
# ---------------------------------------------------------
# stacking_op: add
# ---------------------------------------------------------
# output: activation: softmax, output_shape: (None, 11), use_bias: False
# loss: categorical_crossentropy
# optimizer: Adam
# ---------------------------------------------------------
#
# Model has been saved to:dt_output/dt_20200906 145656_opnn_nets/opnn_nets.h5
# transform_X cost:9.20156216621399
# transform_y cost:0.00645756721496582
# transform_X cost:12.68246078491211
# predict_proba cost:14.50831389427185
# ####################################################################################################
# 11 class detected, inferred as a [multiclass classification] task
# Preparing features cost:0.11052846908569336
# Imputation cost:0.9061117172241211
# Categorical encoding cost:0.45438504219055176
# fit_transform cost:1.565291404724121
# transform_X cost:9.147963523864746
# transform_y cost:0.0052492618560791016
# 1 Physical GPUs, 1 Logical GPUs
# >>>>>>>>>>>>>>>>>>>>>> Model Desc <<<<<<<<<<<<<<<<<<<<<<<
# ---------------------------------------------------------
# inputs:
# ---------------------------------------------------------
# ['all_categorical_vars: (8)', 'input_continuous_all: (80)']
# ---------------------------------------------------------
# embeddings:
# ---------------------------------------------------------
# input_dims: [5, 7, 8, 7, 40, 5, 5, 12]
# output_dims: [20, 20, 20, 20, 20, 20, 20, 20]
# dropout: 0.3
# ---------------------------------------------------------
# dense: dropout: 0
# batch_normalization: False
# ---------------------------------------------------------
# concat_embed_dense: shape: (None, 240)
# ---------------------------------------------------------
# nets: ['opnn_nets']
# ---------------------------------------------------------
# opnn-outer_product: input_shape list(8), output_shape (None, 28)
# opnn-dnn: input_shape (None, 268), output_shape (None, 300)
# ---------------------------------------------------------
# stacking_op: add
# ---------------------------------------------------------
# output: activation: softmax, output_shape: (None, 11), use_bias: False
# loss: categorical_crossentropy
# optimizer: Adam
# ---------------------------------------------------------
#
# Model has been saved to:dt_output/dt_20200906 150340_opnn_nets/opnn_nets.h5
# transform_X cost:8.751934289932251
# transform_y cost:0.005320310592651367
# transform_X cost:12.855948448181152
# predict_proba cost:14.743114471435547
# ####################################################################################################
#
# Fold 4
#  rows of train = 222906 rows of holdout = 95532
# HBox(children=(FloatProgress(value=0.0, max=5.0), HTML(value='')))
# 11 class detected, inferred as a [multiclass classification] task
# Preparing features cost:0.11406922340393066
# Imputation cost:0.8272233009338379
# Categorical encoding cost:0.5522558689117432
# fit_transform cost:1.5916638374328613
# transform_X cost:8.69878339767456
# transform_y cost:0.005413055419921875
# 1 Physical GPUs, 1 Logical GPUs
# >>>>>>>>>>>>>>>>>>>>>> Model Desc <<<<<<<<<<<<<<<<<<<<<<<
# ---------------------------------------------------------
# inputs:
# ---------------------------------------------------------
# ['all_categorical_vars: (8)', 'input_continuous_all: (80)']
# ---------------------------------------------------------
# embeddings:
# ---------------------------------------------------------
# input_dims: [5, 7, 8, 7, 40, 5, 5, 12]
# output_dims: [20, 20, 20, 20, 20, 20, 20, 20]
# dropout: 0.3
# ---------------------------------------------------------
# dense: dropout: 0
# batch_normalization: False
# ---------------------------------------------------------
# concat_embed_dense: shape: (None, 240)
# ---------------------------------------------------------
# nets: ['opnn_nets']
# ---------------------------------------------------------
# opnn-outer_product: input_shape list(8), output_shape (None, 28)
# opnn-dnn: input_shape (None, 268), output_shape (None, 300)
# ---------------------------------------------------------
# stacking_op: add
# ---------------------------------------------------------
# output: activation: softmax, output_shape: (None, 11), use_bias: False
# loss: categorical_crossentropy
# optimizer: Adam
# ---------------------------------------------------------
#
# Model has been saved to:dt_output/dt_20200906 150943_opnn_nets/opnn_nets.h5
# transform_X cost:9.035407304763794
# transform_y cost:0.00550079345703125
# transform_X cost:12.663731098175049
# predict_proba cost:15.030017852783203
# ####################################################################################################
# 11 class detected, inferred as a [multiclass classification] task
# Preparing features cost:0.11287307739257812
# Imputation cost:0.7595441341400146
# Categorical encoding cost:0.46925806999206543
# fit_transform cost:1.4399619102478027
# transform_X cost:9.137311458587646
# transform_y cost:0.005463123321533203
# 1 Physical GPUs, 1 Logical GPUs
# >>>>>>>>>>>>>>>>>>>>>> Model Desc <<<<<<<<<<<<<<<<<<<<<<<
# ---------------------------------------------------------
# inputs:
# ---------------------------------------------------------
# ['all_categorical_vars: (8)', 'input_continuous_all: (80)']
# ---------------------------------------------------------
# embeddings:
# ---------------------------------------------------------
# input_dims: [5, 7, 8, 7, 40, 5, 5, 12]
# output_dims: [20, 20, 20, 20, 20, 20, 20, 20]
# dropout: 0.3
# ---------------------------------------------------------
# dense: dropout: 0
# batch_normalization: False
# ---------------------------------------------------------
# concat_embed_dense: shape: (None, 240)
# ---------------------------------------------------------
# nets: ['opnn_nets']
# ---------------------------------------------------------
# opnn-outer_product: input_shape list(8), output_shape (None, 28)
# opnn-dnn: input_shape (None, 268), output_shape (None, 300)
# ---------------------------------------------------------
# stacking_op: add
# ---------------------------------------------------------
# output: activation: softmax, output_shape: (None, 11), use_bias: False
# loss: categorical_crossentropy
# optimizer: Adam
# ---------------------------------------------------------
#
# Model has been saved to:dt_output/dt_20200906 151610_opnn_nets/opnn_nets.h5
# transform_X cost:8.907685995101929
# transform_y cost:0.005604743957519531
# transform_X cost:12.891903162002563
# predict_proba cost:15.241436958312988
# ####################################################################################################
# 11 class detected, inferred as a [multiclass classification] task
# Preparing features cost:0.11840415000915527
# Imputation cost:0.8402664661407471
# Categorical encoding cost:0.48740386962890625
# fit_transform cost:1.5417914390563965
# transform_X cost:9.008788824081421
# transform_y cost:0.0055811405181884766
# 1 Physical GPUs, 1 Logical GPUs
# >>>>>>>>>>>>>>>>>>>>>> Model Desc <<<<<<<<<<<<<<<<<<<<<<<
# ---------------------------------------------------------
# inputs:
# ---------------------------------------------------------
# ['all_categorical_vars: (8)', 'input_continuous_all: (80)']
# ---------------------------------------------------------
# embeddings:
# ---------------------------------------------------------
# input_dims: [5, 7, 8, 7, 40, 5, 5, 12]
# output_dims: [20, 20, 20, 20, 20, 20, 20, 20]
# dropout: 0.3
# ---------------------------------------------------------
# dense: dropout: 0
# batch_normalization: False
# ---------------------------------------------------------
# concat_embed_dense: shape: (None, 240)
# ---------------------------------------------------------
# nets: ['opnn_nets']
# ---------------------------------------------------------
# opnn-outer_product: input_shape list(8), output_shape (None, 28)
# opnn-dnn: input_shape (None, 268), output_shape (None, 300)
# ---------------------------------------------------------
# stacking_op: add
# ---------------------------------------------------------
# output: activation: softmax, output_shape: (None, 11), use_bias: False
# loss: categorical_crossentropy
# optimizer: Adam
# ---------------------------------------------------------
#
# Model has been saved to:dt_output/dt_20200906 152110_opnn_nets/opnn_nets.h5
# transform_X cost:9.611756086349487
# transform_y cost:0.0068819522857666016
# transform_X cost:12.986684560775757
# predict_proba cost:14.83170461654663
# ####################################################################################################
# 11 class detected, inferred as a [multiclass classification] task
# Preparing features cost:0.11336445808410645
# Imputation cost:0.9060640335083008
# Categorical encoding cost:0.5569584369659424
# fit_transform cost:1.6798555850982666
# transform_X cost:8.70977234840393
# transform_y cost:0.005704641342163086
# 1 Physical GPUs, 1 Logical GPUs
# >>>>>>>>>>>>>>>>>>>>>> Model Desc <<<<<<<<<<<<<<<<<<<<<<<
# ---------------------------------------------------------
# inputs:
# ---------------------------------------------------------
# ['all_categorical_vars: (8)', 'input_continuous_all: (80)']
# ---------------------------------------------------------
# embeddings:
# ---------------------------------------------------------
# input_dims: [5, 7, 8, 7, 40, 5, 5, 12]
# output_dims: [20, 20, 20, 20, 20, 20, 20, 20]
# dropout: 0.3
# ---------------------------------------------------------
# dense: dropout: 0
# batch_normalization: False
# ---------------------------------------------------------
# concat_embed_dense: shape: (None, 240)
# ---------------------------------------------------------
# nets: ['opnn_nets']
# ---------------------------------------------------------
# opnn-outer_product: input_shape list(8), output_shape (None, 28)
# opnn-dnn: input_shape (None, 268), output_shape (None, 300)
# ---------------------------------------------------------
# stacking_op: add
# ---------------------------------------------------------
# output: activation: softmax, output_shape: (None, 11), use_bias: False
# loss: categorical_crossentropy
# optimizer: Adam
# ---------------------------------------------------------
#
# Model has been saved to:dt_output/dt_20200906 152729_opnn_nets/opnn_nets.h5
# transform_X cost:9.023816585540771
# transform_y cost:0.005472898483276367
# transform_X cost:13.808613300323486
# predict_proba cost:15.818638563156128
# ####################################################################################################
# 11 class detected, inferred as a [multiclass classification] task
# Preparing features cost:0.11224532127380371
# Imputation cost:0.752526044845581
# Categorical encoding cost:0.45596742630004883
# fit_transform cost:1.419302225112915
# transform_X cost:8.950264692306519
# transform_y cost:0.005615234375
# 1 Physical GPUs, 1 Logical GPUs
# >>>>>>>>>>>>>>>>>>>>>> Model Desc <<<<<<<<<<<<<<<<<<<<<<<
# ---------------------------------------------------------
# inputs:
# ---------------------------------------------------------
# ['all_categorical_vars: (8)', 'input_continuous_all: (80)']
# ---------------------------------------------------------
# embeddings:
# ---------------------------------------------------------
# input_dims: [5, 7, 8, 7, 40, 5, 5, 12]
# output_dims: [20, 20, 20, 20, 20, 20, 20, 20]
# dropout: 0.3
# ---------------------------------------------------------
# dense: dropout: 0
# batch_normalization: False
# ---------------------------------------------------------
# concat_embed_dense: shape: (None, 240)
# ---------------------------------------------------------
# nets: ['opnn_nets']
# ---------------------------------------------------------
# opnn-outer_product: input_shape list(8), output_shape (None, 28)
# opnn-dnn: input_shape (None, 268), output_shape (None, 300)
# ---------------------------------------------------------
# stacking_op: add
# ---------------------------------------------------------
# output: activation: softmax, output_shape: (None, 11), use_bias: False
# loss: categorical_crossentropy
# optimizer: Adam
# ---------------------------------------------------------
#
# Model has been saved to:dt_output/dt_20200906 153421_opnn_nets/opnn_nets.h5
# transform_X cost:8.972413778305054
# transform_y cost:0.005684614181518555
# transform_X cost:12.79588770866394
# predict_proba cost:14.698138236999512
# ####################################################################################################
#
#
#
# Average Multi Log Loss Stats 1.45605,0.00204
# 43.926 (0.105)

# %%
plot_model(dt[0].get_model().model,rankdir='TB')

# %%
submission_probs.iloc[:,1:] = probs

# probablity combined
submission_probs.to_csv('probs.csv',index =False)

# %%
submission['Stay'] = le_dict['Stay'].inverse_transform(np.argmax(probs,axis =1))

# submission file combined            
submission.to_csv('submission.csv',index =False)

submission.head()
# Out:
#    case_id   Stay
# 0   318439   0-10
# 1   318440  51-60
# 2   318441  21-30
# 3   318442  21-30
# 4   318443  51-60

# %%
model_stats = pd.DataFrame({'submission':submission_name,'accuracy':scores,'validation_loss':avg_loss})

model_stats.head()
# Out:
#               submission   accuracy  validation_loss
# 0  submission_32_0_0.csv  43.899426         1.455591
# 1  submission_32_0_1.csv  43.774861         1.455419
# 2  submission_32_0_2.csv  43.917221         1.455500
# 3  submission_32_0_3.csv  43.830338         1.455303
# 4  submission_32_0_4.csv  43.927690         1.455408

# %%
model_stats.to_csv('model_stats.csv',index =False)
